# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.action_chains import ActionChains
import time 
import string
import openpyxl
import os

# %%
#Loading Selenium Webdriver 
driver = webdriver.Chrome(ChromeDriverManager().install())
wait = WebDriverWait(driver, 5)

# %%
url="https://www.google.com/maps/search/barcelona+restaurants+maps/@41.3925801,2.125341,16z"

# %%
#Opening Google maps 
driver.get(url)
time.sleep(3)

# %%
#Closing the google consent form 
button=driver.find_element(by=By.CLASS_NAME, value='VfPpkd-RLmnJb').click()

# %%
username = driver.find_element(by=By.ID,value="identifierId")
username.send_keys("upcprojectforme@gmail.com")

# %%
driver.find_element(by=By.CLASS_NAME, value="VfPpkd-vQzf8d").click()
time.sleep(3)

# %%
password = driver.find_element(by=By.NAME,value="password")
action = ActionChains(driver)
action.move_to_element(password).click().send_keys("upc12345678").perform()
driver.implicitly_wait(20)
action.perform()

# %%
driver.find_element(by=By.CLASS_NAME, value="VfPpkd-vQzf8d").click()
time.sleep(3)

# %%
shop_name_list=[]
shop_score_list=[]
shop_review_times_list=[]
shop_score_list=[]
shop_location_list=[]

# %%
def one_shop_info():
    driver.implicitly_wait(10)
    shop_name=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[1]/h1').text
    shop_score=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/div[2]/span/span/span').text
    shop_review_times=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/span[1]/span/span/span[2]/span[1]/button').text
    shop_score=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[1]/div[2]/div/div[1]/div[2]/span/span/span').text
    #shop_location=driver.find_element(by=By.CLASS_NAME, value='QSFF4-text gm2-body-2').text
    shop_name_list.append(shop_name)
    shop_score_list.append(shop_score)
    shop_review_times_list.append(shop_review_times)
    shop_score_list.append(shop_score)
    #shop_location.append(shop_location)
    print(shop_name_list)
    back_button=driver.find_element(by=By.XPATH, value='//*[@id="omnibox-singlebox"]/div[1]/div[1]/button/img')
    driver.implicitly_wait(10)
    action = ActionChains(driver)
    action.move_to_element(back_button).click().perform()
    action.perform()

# %%
target = driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a')
#driver.execute_script("arguments[0].scrollIntoView();", driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a'))

# %%
bar = driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]')

# %%
def is_element_exist(driver, class_name):
    """
    判断元素是否存在
    :param driver: 
    :param class_name: 
    :return: 
    """
    el = driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div[3]/div/a')
    if len(el) > 0:
        return True
    else:
        return False

# %%
while True:
    target.send_keys(Keys.PAGE_DOWN)
    print(bar.location.get('y'))

# %%
target.location_once_scrolled_into_view

# %%
button=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]')
target.location_once_scrolled_into_view

# %%
def scroll_into_view(driver, element=None, css_selector=None):
    if (not element) and (not css_selector):
        return
    if css_selector and (not element):
        element = driver.find_element_by_css_selector(css_selector)
    driver.execute_script('arguments[0].scrollIntoView({block: "center"})', element)

# %%
js = "return document.body.scrollHeight"
# 获取滚动条的高度
new_height = driver.execute_script(js)
print(new_height)

# %%
def is_element_exist(driver, class_name):
    """
    判断元素是否存在
    :param driver: 
    :param class_name: 
    :return: 
    """
    el = driver.find_elements_by_class_name(class_name)
    if len(el) > 0:
        return True
    else:
        return False

def handle_selenium_content(driver, url):
    class_name = 'read-more-zhankai'
    if is_element_exist(driver, class_name):
        i = driver.find_element_by_class_name(class_name)
        i.click()
    js = "return document.body.scrollHeight"
    new_height = driver.execute_script(js)
    for i in range(0, new_height, 350):
        time.sleep(0.05)
        driver.execute_script('window.scrollTo(0, %s)' % i)

# %%
dragElement=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]')
action_chains = ActionChains(driver)
action_chains.drag_and_drop_by_offset(dragElement,0,2000)

for i in range(1,25):
#while True:
    i=str(2*i+1)
    if driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div['+i+']/div/a'):
        button=driver.find_element(by=By.XPATH, value='//*[@id="pane"]/div/div[1]/div/div/div[2]/div[1]/div['+i+']/div/a')
        driver.implicitly_wait(10)
        action = ActionChains(driver)
        action.move_to_element(button).click().perform()
        action.perform()
        one_shop_info()
    #else:
        #time.sleep(3)
        #break
# dragElement=driver.find_element_by_xpath("//div[contains(@class,'el-table__body-wrapper is-scrolling')]")
# action_chains = ActionChains(driver)
# action_chains.drag_and_drop_by_offset(dragElement,0,2000)
